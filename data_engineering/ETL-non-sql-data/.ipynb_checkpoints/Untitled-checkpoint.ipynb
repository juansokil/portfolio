# %%
import pandas as pd
import json

# %%
from elasticsearch import Elasticsearch
from elasticsearch import helpers

es = Elasticsearch([{'host':'localhost', 'port': 9200}])
print(es)
# Out:
# <Elasticsearch([{'host': 'localhost', 'port': 9200}])>

# %%
filename='./data_json/datos.json'

with open(filename, 'r') as f:
    object_list = []
    for line in f.readlines():
        object_list.append(json.loads(line))

# %%
for object in object_list:
    #print("loading json file",object['id'])
    es.index(index='youbora', doc_type='doc', body=object)
# Out:
# /home/juanpablosokil/.local/lib/python3.6/site-packages/elasticsearch/connection/base.py:190: ElasticsearchDeprecationWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.16/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchDeprecationWarning)
# /home/juanpablosokil/.local/lib/python3.6/site-packages/elasticsearch/connection/base.py:190: ElasticsearchDeprecationWarning: [types removal] Specifying types in document index requests is deprecated, use the typeless endpoints instead (/{index}/_doc/{id}, /{index}/_doc, or /{index}/_create/{id}).
#   warnings.warn(message, category=ElasticsearchDeprecationWarning)

# %%
objetito=object_list[2]

# %%
objetito['user_id']
# Out:
# '1594521'

# %%
objetito=object_list[32]
objetito
# Out:
# {'end_at': 0,
#  'init_at': 1645135335628,
#  'media_resource': 'https://chromecast.cvattv.com.ar/live/c3eds/TodoNoticias/SA_Live_dash_enc_2A/TodoNoticias.mpd',
#  'type_view': 'LIVE',
#  'token': '10368463517090877624',
#  'cdn': 'Anevia - Flow',
#  'title': 'TN Central',
#  'title2': 'Undefined',
#  'duration': 0,
#  'user_id': '1879085',
#  'rendition': '1920x1080@5.15Mbps',
#  'user_agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.82 Safari/537.36',
#  'device_name': 'PC( Windows )',
#  'device_type': 'PC',
#  'device_vendor': 'Microsoft',
#  'device_model': '',
#  'browser_name': 'Chrome',
#  'browser_ver': 'Chrome 98.0.4758.82',
#  'os': 'Windows',
#  'os_version': 'Windows 10',
#  'ip': '152.168.118.196',
#  'ip_version': 'IPv4',
#  'city': 'San Fernando',
#  'country_code': 'AR',
#  'region': 'LATAM',
#  'isp': 'Personal',
#  'lat': '-34.4459',
#  'lon': '-58.5836',
#  'asn': 7303,
#  'postal_code': '1646',
# ...

# %%
dropped_frames =[]
for object in object_list:
    dropped_frames.append(object['dropped_frames'])

# %%
dropped_frames.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-3055c15284e7> in <module>
# ----> 1 dropped_frames.describe()
#
# AttributeError: 'list' object has no attribute 'describe'

# %%
df = pd.DataFrame({'dropped_frames':dropped_frames})

# %%
df['dropped_frames'].describe()
# Out:
# count    31818.000000
# mean        52.073229
# std        905.254553
# min     -31465.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      31290.000000
# Name: dropped_frames, dtype: float64

# %%
eventos =[]
for object in object_list:
    eventos.append(object['events'])

# %%
eventos
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'event': 'SWITCHING',
#    'unixtime': 1645113285416,
#    'switch_dimension': 'rendition',
#    'switch_new_value': '1280x720@2.65Mbps',
#    'switch_old_value': ''}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'event': 'SWITCHING',
#    'unixtime': 1645135520204,
#    'switch_dimension': 'rendition',
#    'switch_new_value': '1280x720@2.65Mbps',
#    'switch_old_value': '1920x1080@5.15Mbps'},
#   {'event': 'SWITCHING',
#    'unixtime': 1645135580323,
#    'switch_dimension': 'rendition',
#    'switch_new_value': '1920x1080@5.15Mbps',
#    'switch_old_value': '1280x720@2.65Mbps'},
#   {'event': 'SWITCHING',
#    'unixtime': 1645135590295,
#    'switch_dimension': 'rendition',
#    'switch_new_value': '1280x720@2.65Mbps',
#    'switch_old_value': '1920x1080@5.15Mbps'},
#   {'event': 'SWITCHING',
# ...
