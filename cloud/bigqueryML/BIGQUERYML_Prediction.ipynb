# %% [markdown]
# ## MODELADO DE DATOS CON BIGQUERY ML - Regresión Lineal

# %% [markdown]
# En esta notebook se calcula una regresión lineal para una predicción.
# Se carga una base se datos, se entrena el modelo, se lo evalua y se predicen nuevos datos.
# Ademas se trabaja con la explicación a nivel fila y global, para entender que varias son relevantes.

# %%
# %load_ext google.cloud.bigquery
# Out:
# The google.cloud.bigquery extension is already loaded. To reload it, use:
#   %reload_ext google.cloud.bigquery

# %% [markdown]
# Creo una tabla para modelar

# %% [markdown]
# Creo el modelo

# %%
# %%bigquery
#
# # Creating the baseline model
# CREATE OR REPLACE MODEL
#   `proyectos.nps.bigquery_ml_wei_lineal_reg`
#     OPTIONS (model_type='linear_reg', input_label_cols=['nps_numero']
#    ,num_trials=5 ##HIPERPARAMETRO
#    ,max_parallel_trials=3, ##HIPERPARAMETRO
#    l1_reg=hparam_range(0, 1), ##HIPERPARAMETRO
#    l2_reg=hparam_candidates([0, 0.1, 1, 10]) ##HIPERPARAMETRO
#             ) AS
# SELECT
#   wtod_score_modem_avg, wtod_score_modem_stddev, wtod_score_modem_min,  wtod_score_modem_max,
#     wbhp_score_modem_avg, wbhp_score_modem_stddev,  wbhp_score_modem_min,  wbhp_score_modem_max,
#     wts_score_modem_avg, wts_score_modem_stddev, wts_score_modem_min, wts_score_modem_max,
#     wdr_score_modem_avg, wdr_score_modem_stddev,  wdr_score_modem_min,  wdr_score_modem_max,
#     wpl_score_modem_avg, wpl_score_modem_stddev, wpl_score_modem_min, wpl_score_modem_max,
#     wi_score_modem_avg, wi_score_modem_stddev,  wi_score_modem_min,  wi_score_modem_max,
#     wlbu_score_modem_avg, wlbu_score_modem_stddev, wlbu_score_modem_min, wlbu_score_modem_max,
#     ML.FEATURE_CROSS(STRUCT(modem, tecnologia)) AS modem_tecnologia, ## le indico dos variables y me calcula las combinaciones
#     ML.POLYNOMIAL_EXPAND(STRUCT(wi_score_modem_avg), 3) as wi_score_polinomio, ##creates x, x2, x3, etc.
#     ML.BUCKETIZE(wi_score_modem_max, [20, 40, 60, 80]) as wi_score_bucket, ## where split_points is an array
#    nps_numero
# FROM
#   `proyectos.nps.qualtrics_wei_train_data`
# WHERE
#     ABS(MOD(FARM_FINGERPRINT(TO_JSON_STRING(STRUCT(dt, contrato, modem))), 10)) < 8 ##SPLIT Y ENTRENO
# Out:
# Query complete after 0.01s: 100%|██████████| 11/11 [00:00<00:00, 5631.31query/s]
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Obtener las estadisticas de entrenamiento

# %%
# %%bigquery
# SELECT
#   *
# FROM
#   --ML.TRAINING_INFO(MODEL `proyectos.nps.bigquery_ml_wei_lineal_reg`)    #SIN TUNEO HIPERPARAMETROS
#   ML.TRIAL_INFO(MODEL `proyectos.nps.bigquery_ml_wei_lineal_reg`)     #SOLO SI TUNEO HIPERPARAMETROS
# Out:
# Query complete after 0.00s: 100%|██████████| 1/1 [00:00<00:00, 865.70query/s]
# Downloading: 100%|██████████| 5/5 [00:00<00:00,  6.71rows/s]
#    trial_id                                    hyperparameters  \
# 0         1                   {'l1_reg': 1e-14, 'l2_reg': 1.0}
# 1         2  {'l1_reg': 1.1924052757445675e-11, 'l2_reg': 1.0}
# 2         3  {'l1_reg': 2.6958670578562742e-08, 'l2_reg': 0.1}
# 3         4  {'l1_reg': 2.0403139161274637e-10, 'l2_reg': 1.0}
# 4         5  {'l1_reg': 2.0728085351859456e-12, 'l2_reg': 1.0}
#
#      hparam_tuning_evaluation_metrics  training_loss  eval_loss     status  \
# 0  {'r2_score': 0.019128155849764794}      10.979022  11.024662  SUCCEEDED
# 1  {'r2_score': 0.019128155849765127}      10.979022  11.024662  SUCCEEDED
# 2   {'r2_score': 0.01512969937773534}      10.965046  11.069603  SUCCEEDED
# 3   {'r2_score': 0.01912815584976324}      10.979022  11.024662  SUCCEEDED
# 4  {'r2_score': 0.019128155849765127}      10.979022  11.024662  SUCCEEDED
#
#   error_message  is_optimal
# 0          None       False
# 1          None        True
# 2          None       False
# 3          None       False
# 4          None        True

# %% [markdown]
# # Evaluación del modelo

# %%
# %%bigquery
# # Evaluate Model
# SELECT *
# FROM
#   ML.EVALUATE(MODEL `proyectos.nps.bigquery_ml_wei_lineal_reg`,
#     (SELECT *,
#      ML.FEATURE_CROSS(STRUCT(modem, tecnologia)) AS modem_tecnologia,
#      ML.POLYNOMIAL_EXPAND(STRUCT(wi_score_modem_avg), 3) as wi_score_polinomio, ##creates x, x2, x3, etc.
#      ML.BUCKETIZE(wi_score_modem_max, [20, 40, 60, 80]) as wi_score_bucket, ## where split_points is an array   ##SI AGREGO ALGUNA VARIABLE LA DEBO METER ACA TAMBIEN
#      FROM `proyectos.nps.qualtrics_wei_train_data`
#      WHERE ABS(MOD(FARM_FINGERPRINT(TO_JSON_STRING(STRUCT(dt, contrato, modem))), 10)) >= 8 ##SPLIT Y ENTRENO
#     ))
# Out:
# Query complete after 0.00s: 100%|██████████| 3/3 [00:00<00:00, 1549.62query/s]
# Downloading: 100%|██████████| 1/1 [00:00<00:00,  1.26rows/s]
#    trial_id  mean_absolute_error  mean_squared_error  mean_squared_log_error  \
# 0         5             2.929214           11.631282                  0.7284
#
#    median_absolute_error  r2_score  explained_variance
# 0               2.967536 -0.000078           -0.000076

# %%
# %%bigquery
#
# # Use `ML.EVALUATE` function to evaluate model metrics.
# SELECT
#   SQRT(mean_squared_error) AS rmse
# FROM
#   ML.EVALUATE(MODEL `proyectos.nps.bigquery_ml_wei_lineal_reg`)
# Out:
# Query complete after 0.00s: 100%|██████████| 1/1 [00:00<00:00, 577.97query/s]
# Downloading: 100%|██████████| 5/5 [00:00<00:00,  6.29rows/s]
#        rmse
# 0  3.183858
# 1  3.183497
# 2  3.196667
# 3  3.196667
# 4  3.196667

# %% [markdown]
# predicción

# %%
# %%bigquery
#
# # Predict
# SELECT
#   *
# FROM
#   ML.PREDICT(MODEL `proyectos.nps.bigquery_ml_wei_lineal_reg`,
#     (SELECT FARM_FINGERPRINT(CONCAT(CAST(tecnologia AS STRING), wtod_score_modem_min, CAST(modem AS STRING))) as row_fingerprint,
# rand() as random, modem, tecnologia,
#   wtod_score_modem_avg, wtod_score_modem_stddev, wtod_score_modem_min,  wtod_score_modem_max,
#     wbhp_score_modem_avg, wbhp_score_modem_stddev,  wbhp_score_modem_min,  wbhp_score_modem_max,
#     wts_score_modem_avg, wts_score_modem_stddev, wts_score_modem_min, wts_score_modem_max,
#     wdr_score_modem_avg, wdr_score_modem_stddev,  wdr_score_modem_min,  wdr_score_modem_max,
#     wpl_score_modem_avg, wpl_score_modem_stddev, wpl_score_modem_min, wpl_score_modem_max,
#     wi_score_modem_avg, wi_score_modem_stddev,  wi_score_modem_min,  wi_score_modem_max,
#     wlbu_score_modem_avg, wlbu_score_modem_stddev, wlbu_score_modem_min, wlbu_score_modem_max,
#      ML.FEATURE_CROSS(STRUCT(modem, tecnologia)) AS modem_tecnologia,
#      ML.POLYNOMIAL_EXPAND(STRUCT(wi_score_modem_avg), 3) as wi_score_polinomio, ##creates x, x2, x3, etc.
#      ML.BUCKETIZE(wi_score_modem_max, [20, 40, 60, 80]) as wi_score_bucket,
#      FROM `proyectos.nps.qualtrics_wei_train_data` limit 1000));
# Out:
# Query complete after 0.00s: 100%|██████████| 3/3 [00:00<00:00, 1193.94query/s]
# Downloading: 100%|██████████| 1000/1000 [00:00<00:00, 1241.39rows/s]
#      trial_id  predicted_nps_numero      row_fingerprint    random     modem  \
# 0           5              5.073715  4484183361832963093  0.854155  tchn4233
# 1           5              5.100909 -5339490955989020034  0.948686  smbs3686
# 2           5              5.384797  6085560282673740129  0.197126  smbs3890
# 3           5              5.032930  6085560282673740129  0.086771  smbs3890
# 4           5              4.974768  4349173671011907940  0.320301  tchn3848
# ..        ...                   ...                  ...       ...       ...
# 995         5              5.797156 -6530293540636871171  0.532519  smbs5657
# 996         5              5.804819  2916557903978646332  0.454380  smbs5657
# 997         5              5.939232 -6530293540636871171  0.299574  smbs5657
# 998         5              5.903946 -7128826710360303480  0.601135  smbs5657
# 999         5              5.227691  4349173671011907940  0.058300  tchn3848
#
#     tecnologia  wtod_score_modem_avg  wtod_score_modem_stddev  \
# 0          HFC              0.000000                 0.000000
# 1          HFC              0.000000                 0.000000
# 2          HFC              0.000000                 0.000000
# 3          HFC              0.000000                 0.000000
# 4          HFC              0.000000                 0.000000
# ..         ...                   ...                      ...
# 995       FTTH              0.129286                 0.236651
# 996       FTTH             37.041429                 2.639152
# 997       FTTH             12.214286                 8.674285
# 998       FTTH             22.220714                 3.565626
# 999        HFC              0.000000                 0.000000
#
#      wtod_score_modem_min  wtod_score_modem_max  ...  wi_score_modem_stddev  \
# 0                    0.00                 0.000  ...               5.398171
# 1                    0.00                 0.000  ...               0.204888
# 2                    0.00                 0.000  ...               0.000000
# 3                    0.00                 0.000  ...               0.000000
# 4                    0.00                 0.000  ...               0.000000
# ..                    ...                   ...  ...                    ...
# 995                  0.00                 0.600  ...               0.374615
# 996                 34.11                41.610  ...               0.481464
# 997                  0.00                20.360  ...               0.311845
# 998                 18.18                26.345  ...               0.195382
# 999                  0.00                 0.000  ...               0.000000
#
#      wi_score_modem_min  wi_score_modem_max  wlbu_score_modem_avg  \
# 0             42.101187           53.237585              0.000000
# 1             15.923567           16.543624            100.000000
# 2              0.000000            0.000000             67.924286
# 3              0.000000            0.000000             98.961429
# 4              0.000000            0.000000             43.292857
# ..                  ...                 ...                   ...
# 995           24.192073           25.375767              0.000000
# 996           35.203125           36.608116              0.000000
# 997           33.795732           34.655689              0.000000
# 998           32.705793           33.277439              0.000000
# 999            0.000000            0.000000             79.404286
#
#      wlbu_score_modem_stddev  wlbu_score_modem_min  wlbu_score_modem_max  \
# 0                   0.000000                  0.00                  0.00
# 1                   0.000000                100.00                100.00
# 2                   1.831128                 65.56                 70.70
# 3                   0.392998                 98.63                 99.74
# 4                   7.547385                 32.69                 53.30
# ..                       ...                   ...                   ...
# 995                 0.000000                  0.00                  0.00
# 996                 0.000000                  0.00                  0.00
# 997                 0.000000                  0.00                  0.00
# 998                 0.000000                  0.00                  0.00
# 999                 2.849765                 75.80                 83.37
#
#                           modem_tecnologia  \
# 0     {'modem_tecnologia': 'tchn4233_HFC'}
# 1     {'modem_tecnologia': 'smbs3686_HFC'}
# 2     {'modem_tecnologia': 'smbs3890_HFC'}
# 3     {'modem_tecnologia': 'smbs3890_HFC'}
# 4     {'modem_tecnologia': 'tchn3848_HFC'}
# ..                                     ...
# 995  {'modem_tecnologia': 'smbs5657_FTTH'}
# 996  {'modem_tecnologia': 'smbs5657_FTTH'}
# 997  {'modem_tecnologia': 'smbs5657_FTTH'}
# 998  {'modem_tecnologia': 'smbs5657_FTTH'}
# 999   {'modem_tecnologia': 'tchn3848_HFC'}
#
#                                     wi_score_polinomio  wi_score_bucket
# 0    {'wi_score_modem_avg': 48.568663455187604, 'wi...            bin_3
# 1    {'wi_score_modem_avg': 16.221653628443587, 'wi...            bin_1
# 2    {'wi_score_modem_avg': 0.0, 'wi_score_modem_av...            bin_1
# 3    {'wi_score_modem_avg': 0.0, 'wi_score_modem_av...            bin_1
# 4    {'wi_score_modem_avg': 0.0, 'wi_score_modem_av...            bin_1
# ..                                                 ...              ...
# 995  {'wi_score_modem_avg': 24.784317704664623, 'wi...            bin_2
# 996  {'wi_score_modem_avg': 36.10663608954553, 'wi_...            bin_2
# 997  {'wi_score_modem_avg': 34.31109845877745, 'wi_...            bin_2
# 998  {'wi_score_modem_avg': 32.9792731985244, 'wi_s...            bin_2
# 999  {'wi_score_modem_avg': 0.0, 'wi_score_modem_av...            bin_1
#
# [1000 rows x 37 columns]

# %% [markdown]
# ## Explicar el modelo a nivel fila

# %%
# %%bigquery
#
# #Explain Predictions
# SELECT
#   *
# FROM
#   ML.EXPLAIN_PREDICT(MODEL `teco-prod-wei-dev-29cd.nps.bigquery_ml_wei_lineal_reg`,
#     (SELECT *,
#      ML.FEATURE_CROSS(STRUCT(modem, tecnologia)) AS modem_tecnologia,
#      ML.POLYNOMIAL_EXPAND(STRUCT(wi_score_modem_avg), 3) as wi_score_polinomio, ##creates x, x2, x3, etc.
#      ML.BUCKETIZE(wi_score_modem_max, [20, 40, 60, 80]) as wi_score_bucket,
#      FROM `teco-prod-wei-dev-29cd.nps.qualtrics_wei_train_data` limit 1000),
#     STRUCT(3 as top_k_features));
# Out:
# Query complete after 0.00s: 100%|██████████| 2/2 [00:00<00:00, 894.50query/s]
# Downloading: 100%|██████████| 1000/1000 [00:01<00:00, 792.02rows/s]
#      trial_id  predicted_nps  probability  \
# 0           1              0     0.559779
# 1           1              0     0.560045
# 2           1              0     0.559274
# 3           1              1     0.531060
# 4           1              1     0.534394
# ..        ...            ...          ...
# 995         1              1     0.525311
# 996         1              1     0.525121
# 997         1              1     0.525073
# 998         1              1     0.525791
# 999         1              1     0.527357
#
#                               top_feature_attributions  \
# 0    [{'feature': 'modem_tecnologia_modem_tecnologi...
# 1    [{'feature': 'modem_tecnologia_modem_tecnologi...
# 2    [{'feature': 'modem_tecnologia_modem_tecnologi...
# 3    [{'feature': 'modem_tecnologia_modem_tecnologi...
# 4    [{'feature': 'modem_tecnologia_modem_tecnologi...
# ..                                                 ...
# 995  [{'feature': 'modem_tecnologia_modem_tecnologi...
# 996  [{'feature': 'modem_tecnologia_modem_tecnologi...
# 997  [{'feature': 'modem_tecnologia_modem_tecnologi...
# 998  [{'feature': 'modem_tecnologia_modem_tecnologi...
# 999  [{'feature': 'modem_tecnologia_modem_tecnologi...
#
#      baseline_prediction_value  prediction_value  approximation_error  \
# 0                     0.051289         -0.240266                  0.0
# 1                     0.051289         -0.241343                  0.0
# 2                     0.051289         -0.238214                  0.0
# 3                     0.051289          0.124398                  0.0
# 4                     0.051289          0.137792                  0.0
# ..                         ...               ...                  ...
# 995                   0.051289          0.101329                  0.0
# 996                   0.051289          0.100567                  0.0
# 997                   0.051289          0.100377                  0.0
# 998                   0.051289          0.103257                  0.0
# 999                   0.051289          0.109538                  0.0
#
#      contrato tecnologia     modem  ...  wi_score_modem_avg  \
# 0    13045315        HFC  kaon3000  ...            0.000000
# 1    12986951        HFC  kaon3000  ...            0.000000
# 2    38589740        HFC  kaon3000  ...            0.000000
# 3    13102422        HFC  smbs3686  ...           43.613351
# 4    79147178        HFC  smbs3686  ...           16.608500
# ..        ...        ...       ...  ...                 ...
# 995  89809987        HFC  tchn3848  ...            0.000000
# 996  60632404        HFC  tchn3848  ...            0.000000
# 997  39953395        HFC  tchn3848  ...            0.000000
# 998  12932586        HFC  tchn3848  ...            0.000000
# 999  10242912        HFC  tchn3848  ...            0.000000
#
#      wlbu_score_modem_avg  wtod_score_modem_min  wbhp_score_modem_min  \
# 0                0.000000                   0.0             10.000000
# 1                0.000000                   0.0              0.000000
# 2                0.000000                   0.0             28.000000
# 3              100.000000                   0.0             10.000000
# 4               71.226250                   0.0             46.666667
# ..                    ...                   ...                   ...
# 995             96.135000                   0.0             17.000000
# 996            100.000000                   0.0              1.666667
# 997             11.821429                   0.0              0.000000
# 998             95.750000                   0.0             22.727273
# 999              5.233333                   0.0             80.000000
#
#      wts_score_modem_min  wdr_score_modem_min  wpl_score_modem_min  \
# 0                  0.000        -5.603301e-05                  NaN
# 1                  0.000        -1.018172e-06                  NaN
# 2                  0.000        -1.040834e-15                  NaN
# 3                 93.020         2.400020e+00            60.000000
# 4                 23.460         4.865487e+00            72.280000
# ..                   ...                  ...                  ...
# 995                5.960         7.745482e-01            40.000000
# 996               14.250         1.000001e+00            77.003333
# 997                5.755         5.102041e-01             0.000000
# 998                9.720         3.999911e-01            65.054545
# 999               15.950         8.137122e-01             0.000000
#
#      wi_score_modem_min  wlbu_score_modem_min  \
# 0              0.000000                  0.00
# 1              0.000000                  0.00
# 2              0.000000                  0.00
# 3             42.448276                100.00
# 4             16.336276                 67.60
# ..                  ...                   ...
# 995            0.000000                 92.79
# 996            0.000000                100.00
# 997            0.000000                  6.41
# 998            0.000000                 94.81
# 999            0.000000                  3.85
#
#                          modem_tecnologia
# 0    {'modem_tecnologia': 'kaon3000_HFC'}
# 1    {'modem_tecnologia': 'kaon3000_HFC'}
# 2    {'modem_tecnologia': 'kaon3000_HFC'}
# 3    {'modem_tecnologia': 'smbs3686_HFC'}
# 4    {'modem_tecnologia': 'smbs3686_HFC'}
# ..                                    ...
# 995  {'modem_tecnologia': 'tchn3848_HFC'}
# 996  {'modem_tecnologia': 'tchn3848_HFC'}
# 997  {'modem_tecnologia': 'tchn3848_HFC'}
# 998  {'modem_tecnologia': 'tchn3848_HFC'}
# 999  {'modem_tecnologia': 'tchn3848_HFC'}
#
# [1000 rows x 27 columns]
